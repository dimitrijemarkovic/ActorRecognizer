# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitrijemarkovic/ActorRecognizer/blob/main/resnet_original.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dimitrijemarkovic/ActorRecognizer
# Out:
# Cloning into 'ActorRecognizer'...
# remote: Enumerating objects: 18276, done.
# remote: Counting objects: 100% (412/412), done.
# remote: Compressing objects: 100% (369/369), done.
# remote: Total 18276 (delta 53), reused 231 (delta 43), pack-reused 17864
# Receiving objects: 100% (18276/18276), 547.44 MiB | 13.27 MiB/s, done.
# Resolving deltas: 100% (266/266), done.
# Updating files: 100% (35088/35088), done.

# %%
# %cd ActorRecognizer
# Out:
# /content/ActorRecognizer

# %%
# %run 'Treniranje originalnog resnet modela.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...
