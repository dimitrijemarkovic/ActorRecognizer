# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitrijemarkovic/ActorRecognizer/blob/main/Treniranje_Resnet_modela_sa_Adam_optimizatorom_i_50_epoha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dimitrijemarkovic/ActorRecognizer
# Out:
# Cloning into 'ActorRecognizer'...
# remote: Enumerating objects: 18473, done.
# remote: Counting objects: 100% (609/609), done.
# remote: Compressing objects: 100% (516/516), done.
# remote: Total 18473 (delta 145), reused 373 (delta 93), pack-reused 17864
# Receiving objects: 100% (18473/18473), 556.24 MiB | 15.96 MiB/s, done.
# Resolving deltas: 100% (358/358), done.
# Updating files: 100% (35156/35156), done.

# %%
# %cd ActorRecognizer
# Out:
# /content/ActorRecognizer

# %%
# %run '[RESNET] conv + fc slojevi, 50 epoha, Adam, lr=1e-3.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...

# %%
# %run '[RESNET] conv + fc slojevi, 50 epoha, Adam, lr=1e-4.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...

# %%
# %run '[RESNET] conv + fc slojevi, 50 epoha, Adam, lr=1e-5.ipynb'
