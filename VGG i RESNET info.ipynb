# %%
import torch
import torch.nn as nn
from torchvision import models

# %%
resnet = models.resnet50(pretrained=True)
resnet
# Out:
# C:\Users\Dida\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Dida\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
vgg = models.vgg16(pretrained=True)
# Out:
# C:\Users\Dida\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
vgg
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
def print_model_parameters(model):
    total_params = 0
    for name, param in model.named_parameters():
        if param.requires_grad:
            print(f"Sloj: {name} | Broj parametara: {param.numel()}")
            total_params += param.numel()
    print(f"\nUkupan broj parametara: {total_params}")

# %%
def print_resnet_parameters(model):
    components = {
        "conv1": model.conv1,
        "bn1": model.bn1,
        "layer1": model.layer1,
        "layer2": model.layer2,
        "layer3": model.layer3,
        "layer4": model.layer4,
        "fc": model.fc
    }

    for name, component in components.items():
        total_params = sum(p.numel() for p in component.parameters() if p.requires_grad)
        print(f"Komponenta: {name} | Broj parametara: {total_params}")

# %%
print("Parametri Resnet modela:")
print_model_parameters(resnet)
# Out:
# Parametri Resnet modela:
# Sloj: conv1.weight | Broj parametara: 9408
# Sloj: bn1.weight | Broj parametara: 64
# Sloj: bn1.bias | Broj parametara: 64
# Sloj: layer1.0.conv1.weight | Broj parametara: 4096
# Sloj: layer1.0.bn1.weight | Broj parametara: 64
# Sloj: layer1.0.bn1.bias | Broj parametara: 64
# Sloj: layer1.0.conv2.weight | Broj parametara: 36864
# Sloj: layer1.0.bn2.weight | Broj parametara: 64
# Sloj: layer1.0.bn2.bias | Broj parametara: 64
# Sloj: layer1.0.conv3.weight | Broj parametara: 16384
# Sloj: layer1.0.bn3.weight | Broj parametara: 256
# Sloj: layer1.0.bn3.bias | Broj parametara: 256
# Sloj: layer1.0.downsample.0.weight | Broj parametara: 16384
# Sloj: layer1.0.downsample.1.weight | Broj parametara: 256
# Sloj: layer1.0.downsample.1.bias | Broj parametara: 256
# Sloj: layer1.1.conv1.weight | Broj parametara: 16384
# Sloj: layer1.1.bn1.weight | Broj parametara: 64
# Sloj: layer1.1.bn1.bias | Broj parametara: 64
# Sloj: layer1.1.conv2.weight | Broj parametara: 36864
# Sloj: layer1.1.bn2.weight | Broj parametara: 64
# Sloj: layer1.1.bn2.bias | Broj parametara: 64
# Sloj: layer1.1.conv3.weight | Broj parametara: 16384
# Sloj: layer1.1.bn3.weight | Broj parametara: 256
# Sloj: layer1.1.bn3.bias | Broj parametara: 256
# Sloj: layer1.2.conv1.weight | Broj parametara: 16384
# Sloj: layer1.2.bn1.weight | Broj parametara: 64
# Sloj: layer1.2.bn1.bias | Broj parametara: 64
# Sloj: layer1.2.conv2.weight | Broj parametara: 36864
# Sloj: layer1.2.bn2.weight | Broj parametara: 64
# Sloj: layer1.2.bn2.bias | Broj parametara: 64
# Sloj: layer1.2.conv3.weight | Broj parametara: 16384
# Sloj: layer1.2.bn3.weight | Broj parametara: 256
# Sloj: layer1.2.bn3.bias | Broj parametara: 256
# Sloj: layer2.0.conv1.weight | Broj parametara: 32768
# Sloj: layer2.0.bn1.weight | Broj parametara: 128
# Sloj: layer2.0.bn1.bias | Broj parametara: 128
# Sloj: layer2.0.conv2.weight | Broj parametara: 147456
# Sloj: layer2.0.bn2.weight | Broj parametara: 128
# Sloj: layer2.0.bn2.bias | Broj parametara: 128
# Sloj: layer2.0.conv3.weight | Broj parametara: 65536
# Sloj: layer2.0.bn3.weight | Broj parametara: 512
# Sloj: layer2.0.bn3.bias | Broj parametara: 512
# Sloj: layer2.0.downsample.0.weight | Broj parametara: 131072
# Sloj: layer2.0.downsample.1.weight | Broj parametara: 512
# Sloj: layer2.0.downsample.1.bias | Broj parametara: 512
# Sloj: layer2.1.conv1.weight | Broj parametara: 65536
# Sloj: layer2.1.bn1.weight | Broj parametara: 128
# Sloj: layer2.1.bn1.bias | Broj parametara: 128
# Sloj: layer2.1.conv2.weight | Broj parametara: 147456
# Sloj: layer2.1.bn2.weight | Broj parametara: 128
# Sloj: layer2.1.bn2.bias | Broj parametara: 128
# Sloj: layer2.1.conv3.weight | Broj parametara: 65536
# Sloj: layer2.1.bn3.weight | Broj parametara: 512
# Sloj: layer2.1.bn3.bias | Broj parametara: 512
# Sloj: layer2.2.conv1.weight | Broj parametara: 65536
# Sloj: layer2.2.bn1.weight | Broj parametara: 128
# Sloj: layer2.2.bn1.bias | Broj parametara: 128
# Sloj: layer2.2.conv2.weight | Broj parametara: 147456
# Sloj: layer2.2.bn2.weight | Broj parametara: 128
# Sloj: layer2.2.bn2.bias | Broj parametara: 128
# Sloj: layer2.2.conv3.weight | Broj parametara: 65536
# Sloj: layer2.2.bn3.weight | Broj parametara: 512
# Sloj: layer2.2.bn3.bias | Broj parametara: 512
# Sloj: layer2.3.conv1.weight | Broj parametara: 65536
# Sloj: layer2.3.bn1.weight | Broj parametara: 128
# Sloj: layer2.3.bn1.bias | Broj parametara: 128
# Sloj: layer2.3.conv2.weight | Broj parametara: 147456
# Sloj: layer2.3.bn2.weight | Broj parametara: 128
# Sloj: layer2.3.bn2.bias | Broj parametara: 128
# Sloj: layer2.3.conv3.weight | Broj parametara: 65536
# Sloj: layer2.3.bn3.weight | Broj parametara: 512
# Sloj: layer2.3.bn3.bias | Broj parametara: 512
# Sloj: layer3.0.conv1.weight | Broj parametara: 131072
# Sloj: layer3.0.bn1.weight | Broj parametara: 256
# Sloj: layer3.0.bn1.bias | Broj parametara: 256
# Sloj: layer3.0.conv2.weight | Broj parametara: 589824
# Sloj: layer3.0.bn2.weight | Broj parametara: 256
# Sloj: layer3.0.bn2.bias | Broj parametara: 256
# Sloj: layer3.0.conv3.weight | Broj parametara: 262144
# Sloj: layer3.0.bn3.weight | Broj parametara: 1024
# Sloj: layer3.0.bn3.bias | Broj parametara: 1024
# Sloj: layer3.0.downsample.0.weight | Broj parametara: 524288
# Sloj: layer3.0.downsample.1.weight | Broj parametara: 1024
# Sloj: layer3.0.downsample.1.bias | Broj parametara: 1024
# Sloj: layer3.1.conv1.weight | Broj parametara: 262144
# Sloj: layer3.1.bn1.weight | Broj parametara: 256
# Sloj: layer3.1.bn1.bias | Broj parametara: 256
# Sloj: layer3.1.conv2.weight | Broj parametara: 589824
# Sloj: layer3.1.bn2.weight | Broj parametara: 256
# Sloj: layer3.1.bn2.bias | Broj parametara: 256
# Sloj: layer3.1.conv3.weight | Broj parametara: 262144
# Sloj: layer3.1.bn3.weight | Broj parametara: 1024
# Sloj: layer3.1.bn3.bias | Broj parametara: 1024
# Sloj: layer3.2.conv1.weight | Broj parametara: 262144
# Sloj: layer3.2.bn1.weight | Broj parametara: 256
# Sloj: layer3.2.bn1.bias | Broj parametara: 256
# Sloj: layer3.2.conv2.weight | Broj parametara: 589824
# Sloj: layer3.2.bn2.weight | Broj parametara: 256
# Sloj: layer3.2.bn2.bias | Broj parametara: 256
# Sloj: layer3.2.conv3.weight | Broj parametara: 262144
# Sloj: layer3.2.bn3.weight | Broj parametara: 1024
# Sloj: layer3.2.bn3.bias | Broj parametara: 1024
# Sloj: layer3.3.conv1.weight | Broj parametara: 262144
# Sloj: layer3.3.bn1.weight | Broj parametara: 256
# Sloj: layer3.3.bn1.bias | Broj parametara: 256
# Sloj: layer3.3.conv2.weight | Broj parametara: 589824
# Sloj: layer3.3.bn2.weight | Broj parametara: 256
# Sloj: layer3.3.bn2.bias | Broj parametara: 256
# Sloj: layer3.3.conv3.weight | Broj parametara: 262144
# Sloj: layer3.3.bn3.weight | Broj parametara: 1024
# Sloj: layer3.3.bn3.bias | Broj parametara: 1024
# Sloj: layer3.4.conv1.weight | Broj parametara: 262144
# Sloj: layer3.4.bn1.weight | Broj parametara: 256
# Sloj: layer3.4.bn1.bias | Broj parametara: 256
# Sloj: layer3.4.conv2.weight | Broj parametara: 589824
# Sloj: layer3.4.bn2.weight | Broj parametara: 256
# Sloj: layer3.4.bn2.bias | Broj parametara: 256
# Sloj: layer3.4.conv3.weight | Broj parametara: 262144
# Sloj: layer3.4.bn3.weight | Broj parametara: 1024
# Sloj: layer3.4.bn3.bias | Broj parametara: 1024
# Sloj: layer3.5.conv1.weight | Broj parametara: 262144
# Sloj: layer3.5.bn1.weight | Broj parametara: 256
# Sloj: layer3.5.bn1.bias | Broj parametara: 256
# Sloj: layer3.5.conv2.weight | Broj parametara: 589824
# Sloj: layer3.5.bn2.weight | Broj parametara: 256
# Sloj: layer3.5.bn2.bias | Broj parametara: 256
# Sloj: layer3.5.conv3.weight | Broj parametara: 262144
# Sloj: layer3.5.bn3.weight | Broj parametara: 1024
# Sloj: layer3.5.bn3.bias | Broj parametara: 1024
# Sloj: layer4.0.conv1.weight | Broj parametara: 524288
# Sloj: layer4.0.bn1.weight | Broj parametara: 512
# Sloj: layer4.0.bn1.bias | Broj parametara: 512
# Sloj: layer4.0.conv2.weight | Broj parametara: 2359296
# Sloj: layer4.0.bn2.weight | Broj parametara: 512
# Sloj: layer4.0.bn2.bias | Broj parametara: 512
# Sloj: layer4.0.conv3.weight | Broj parametara: 1048576
# Sloj: layer4.0.bn3.weight | Broj parametara: 2048
# Sloj: layer4.0.bn3.bias | Broj parametara: 2048
# Sloj: layer4.0.downsample.0.weight | Broj parametara: 2097152
# Sloj: layer4.0.downsample.1.weight | Broj parametara: 2048
# Sloj: layer4.0.downsample.1.bias | Broj parametara: 2048
# Sloj: layer4.1.conv1.weight | Broj parametara: 1048576
# Sloj: layer4.1.bn1.weight | Broj parametara: 512
# Sloj: layer4.1.bn1.bias | Broj parametara: 512
# Sloj: layer4.1.conv2.weight | Broj parametara: 2359296
# Sloj: layer4.1.bn2.weight | Broj parametara: 512
# Sloj: layer4.1.bn2.bias | Broj parametara: 512
# Sloj: layer4.1.conv3.weight | Broj parametara: 1048576
# Sloj: layer4.1.bn3.weight | Broj parametara: 2048
# Sloj: layer4.1.bn3.bias | Broj parametara: 2048
# Sloj: layer4.2.conv1.weight | Broj parametara: 1048576
# Sloj: layer4.2.bn1.weight | Broj parametara: 512
# Sloj: layer4.2.bn1.bias | Broj parametara: 512
# Sloj: layer4.2.conv2.weight | Broj parametara: 2359296
# Sloj: layer4.2.bn2.weight | Broj parametara: 512
# Sloj: layer4.2.bn2.bias | Broj parametara: 512
# Sloj: layer4.2.conv3.weight | Broj parametara: 1048576
# Sloj: layer4.2.bn3.weight | Broj parametara: 2048
# Sloj: layer4.2.bn3.bias | Broj parametara: 2048
# Sloj: fc.weight | Broj parametara: 2048000
# Sloj: fc.bias | Broj parametara: 1000
#
# Ukupan broj parametara: 25557032

# %%
print("Broj parametara Resnet modela po komponentama")
print_resnet_parameters(resnet)
# Out:
# Broj parametara Resnet modela po komponentama
# Komponenta: conv1 | Broj parametara: 9408
# Komponenta: bn1 | Broj parametara: 128
# Komponenta: layer1 | Broj parametara: 215808
# Komponenta: layer2 | Broj parametara: 1219584
# Komponenta: layer3 | Broj parametara: 7098368
# Komponenta: layer4 | Broj parametara: 14964736
# Komponenta: fc | Broj parametara: 2049000

# %%
print("Parametri VGG modela:")
print_model_parameters(vgg)
# Out:
# Parametri VGG modela:
# Sloj: features.0.weight | Broj parametara: 1728
# Sloj: features.0.bias | Broj parametara: 64
# Sloj: features.2.weight | Broj parametara: 36864
# Sloj: features.2.bias | Broj parametara: 64
# Sloj: features.5.weight | Broj parametara: 73728
# Sloj: features.5.bias | Broj parametara: 128
# Sloj: features.7.weight | Broj parametara: 147456
# Sloj: features.7.bias | Broj parametara: 128
# Sloj: features.10.weight | Broj parametara: 294912
# Sloj: features.10.bias | Broj parametara: 256
# Sloj: features.12.weight | Broj parametara: 589824
# Sloj: features.12.bias | Broj parametara: 256
# Sloj: features.14.weight | Broj parametara: 589824
# Sloj: features.14.bias | Broj parametara: 256
# Sloj: features.17.weight | Broj parametara: 1179648
# Sloj: features.17.bias | Broj parametara: 512
# Sloj: features.19.weight | Broj parametara: 2359296
# Sloj: features.19.bias | Broj parametara: 512
# Sloj: features.21.weight | Broj parametara: 2359296
# Sloj: features.21.bias | Broj parametara: 512
# Sloj: features.24.weight | Broj parametara: 2359296
# Sloj: features.24.bias | Broj parametara: 512
# Sloj: features.26.weight | Broj parametara: 2359296
# Sloj: features.26.bias | Broj parametara: 512
# Sloj: features.28.weight | Broj parametara: 2359296
# Sloj: features.28.bias | Broj parametara: 512
# Sloj: classifier.0.weight | Broj parametara: 102760448
# Sloj: classifier.0.bias | Broj parametara: 4096
# Sloj: classifier.3.weight | Broj parametara: 16777216
# Sloj: classifier.3.bias | Broj parametara: 4096
# Sloj: classifier.6.weight | Broj parametara: 4096000
# Sloj: classifier.6.bias | Broj parametara: 1000
#
# Ukupan broj parametara: 138357544
