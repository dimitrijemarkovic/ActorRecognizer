# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitrijemarkovic/ActorRecognizer/blob/main/Evaluacija_modela.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dimitrijemarkovic/ActorRecognizer
# Out:
# Cloning into 'ActorRecognizer'...
# remote: Enumerating objects: 18435, done.
# remote: Counting objects: 100% (571/571), done.
# remote: Compressing objects: 100% (489/489), done.
# remote: Total 18435 (delta 128), reused 346 (delta 82), pack-reused 17864
# Receiving objects: 100% (18435/18435), 553.95 MiB | 14.27 MiB/s, done.
# Resolving deltas: 100% (341/341), done.
# Updating files: 100% (35149/35149), done.

# %%
# %cd ActorRecognizer
# Out:
# /content/ActorRecognizer

# %%
# %run 'Treniranje i evaluacija najboljih vgg i resnet modela.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...
