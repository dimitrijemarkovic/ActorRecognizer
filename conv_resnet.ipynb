# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitrijemarkovic/ActorRecognizer/blob/main/conv_resnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dimitrijemarkovic/ActorRecognizer
# Out:
# Cloning into 'ActorRecognizer'...
# remote: Enumerating objects: 18269, done.
# remote: Counting objects: 100% (405/405), done.
# remote: Compressing objects: 100% (363/363), done.
# remote: Total 18269 (delta 49), reused 229 (delta 42), pack-reused 17864
# Receiving objects: 100% (18269/18269), 547.38 MiB | 30.28 MiB/s, done.
# Resolving deltas: 100% (262/262), done.
# Updating files: 100% (35085/35085), done.

# %%
# %cd ActorRecognizer
# Out:
# /content/ActorRecognizer

# %%
# %run 'Treniranje konvolutivnih slojeva.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...
