# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitrijemarkovic/ActorRecognizer/blob/main/Treniranje_najbolje_resnet_modela_sa_razlicitim_lr_ovima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dimitrijemarkovic/ActorRecognizer
# Out:
# Cloning into 'ActorRecognizer'...
# remote: Enumerating objects: 18420, done.
# remote: Counting objects: 100% (556/556), done.
# remote: Compressing objects: 100% (478/478), done.
# remote: Total 18420 (delta 118), reused 339 (delta 78), pack-reused 17864
# Receiving objects: 100% (18420/18420), 554.77 MiB | 36.62 MiB/s, done.
# Resolving deltas: 100% (331/331), done.
# Updating files: 100% (35144/35144), done.

# %%
# %cd ActorRecognizer
# Out:
# /content/ActorRecognizer

# %%
# %run '[RESNET] Treniranje konvolutivnih slojeva resnet modela sa vise razlicitih lr-ova.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...
