# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitrijemarkovic/ActorRecognizer/blob/main/Treniranje_Resnet_modela_sa_Adam_optimizatorom_i_50_epoha_lr%3D1e_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dimitrijemarkovic/ActorRecognizer
# Out:
# Cloning into 'ActorRecognizer'...
# remote: Enumerating objects: 18476, done.
# remote: Counting objects: 100% (612/612), done.
# remote: Compressing objects: 100% (521/521), done.
# remote: Total 18476 (delta 145), reused 372 (delta 91), pack-reused 17864
# Receiving objects: 100% (18476/18476), 556.32 MiB | 34.03 MiB/s, done.
# Resolving deltas: 100% (358/358), done.
# Updating files: 100% (35157/35157), done.

# %%
# %cd ActorRecognizer
# Out:
# /content/ActorRecognizer

# %%
# %run '[RESNET] conv + fc slojevi, 50 epoha, Adam, lr=1e-4.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...

# %%
# %run '[RESNET] conv + fc slojevi, 50 epoha, Adam, lr=1e-5.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...
