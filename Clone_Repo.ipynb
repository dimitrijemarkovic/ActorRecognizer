# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitrijemarkovic/ActorRecognizer/blob/main/Clone_Repo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dimitrijemarkovic/ActorRecognizer
# Out:
# Cloning into 'ActorRecognizer'...
# remote: Enumerating objects: 18238, done.
# remote: Counting objects: 100% (374/374), done.
# remote: Compressing objects: 100% (352/352), done.
# remote: Total 18238 (delta 29), reused 198 (delta 22), pack-reused 17864
# Receiving objects: 100% (18238/18238), 462.69 MiB | 15.78 MiB/s, done.
# Resolving deltas: 100% (242/242), done.
# Updating files: 100% (35078/35078), done.

# %%
# !ls
# Out:
# ActorRecognizer  sample_data

# %%
# %cd ActorRecognizer
# Out:
# /content/ActorRecognizer

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %ls
# !git pull
# Out:
#  105_classes_pins_dataset/   test/
#  model.pth                   trening/
# 'Model Training.ipynb'      'Treniranje potpuno povezanog sloja modela + vise epoha.ipynb'
#  README.md                   validate/
#  split_data.ipynb            VGG16.ipynb
# Already up to date.

# %%
# %run 'Treniranje potpuno povezanog sloja modela + vise epoha.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	resnet_only_fc_learning.pth
# 	training_validation_accuracy.png
# 	training_validation_loss.png
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add -A

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   resnet_only_fc_learning.pth
# 	new file:   training_validation_accuracy.png
# 	new file:   training_validation_loss.png

# %%
# !git commit -m "Istreniran resnet sa samo fc slojem i sacuvani plotovi"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@c9f0e57d704b.(none)')

# %%
# !git config --global user.email "dimitrijedidamarkovic@gmail.com"

# %%
# !git commit -m "Istreniran resnet sa samo fc slojem i sacuvani plotovi"
# Out:
# [main adc1617b] Istreniran resnet sa samo fc slojem i sacuvani plotovi
#  3 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 resnet_only_fc_learning.pth
#  create mode 100644 training_validation_accuracy.png
#  create mode 100644 training_validation_loss.png

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.name "dimitrijemarkovic"

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote set-url origin https://{dimitrijemarkovic}:{dimitrijedida00}@github.com/dimitrijemarkovic/ActorRecognizer

# %%
# !git push
# Out:
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/dimitrijemarkovic/ActorRecognizer/'
