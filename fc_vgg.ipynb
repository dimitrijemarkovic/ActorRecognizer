# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitrijemarkovic/ActorRecognizer/blob/main/fc_vgg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dimitrijemarkovic/ActorRecognizer
# Out:
# Cloning into 'ActorRecognizer'...
# remote: Enumerating objects: 18320, done.
# remote: Counting objects: 100% (456/456), done.
# remote: Compressing objects: 100% (398/398), done.
# remote: Total 18320 (delta 79), reused 262 (delta 58), pack-reused 17864
# Receiving objects: 100% (18320/18320), 549.34 MiB | 33.04 MiB/s, done.
# Resolving deltas: 100% (292/292), done.
# Updating files: 100% (35097/35097), done.

# %%
# %cd ActorRecognizer
# Out:
# /content/ActorRecognizer

# %%
# %run 'Treniranje potpuno povezanog sloja vgg modela + vise epoha.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...

# %%
data:image/png;base64,...
