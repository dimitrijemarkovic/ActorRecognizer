# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitrijemarkovic/ActorRecognizer/blob/main/Treniranje_svih_VGG_modela.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dimitrijemarkovic/ActorRecognizer
# Out:
# Cloning into 'ActorRecognizer'...
# remote: Enumerating objects: 18336, done.
# remote: Counting objects: 100% (472/472), done.
# remote: Compressing objects: 100% (408/408), done.
# remote: Total 18336 (delta 90), reused 272 (delta 64), pack-reused 17864
# Receiving objects: 100% (18336/18336), 549.90 MiB | 37.08 MiB/s, done.
# Resolving deltas: 100% (303/303), done.
# Updating files: 100% (35100/35100), done.

# %%
# %cd ActorRecognizer
# Out:
# /content/ActorRecognizer

# %%
# %run '[VGG] Treniranje konvolutivnih slojeva vgg modela.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...

# %%
# %run '[VGG] Treniranje i fc i conv slojeva vgg modela.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...

# %%
# %run '[VGG] Treniranje potpuno povezanog sloja vgg modela + vise epoha.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...
