# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitrijemarkovic/ActorRecognizer/blob/main/VGG/razlciti%20parametri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dimitrijemarkovic/ActorRecognizer
# Out:
# Cloning into 'ActorRecognizer'...
# remote: Enumerating objects: 18378, done.
# remote: Counting objects: 100% (514/514), done.
# remote: Compressing objects: 100% (441/441), done.
# remote: Total 18378 (delta 106), reused 306 (delta 73), pack-reused 17864
# Receiving objects: 100% (18378/18378), 551.37 MiB | 32.18 MiB/s, done.
# Resolving deltas: 100% (319/319), done.
# Updating files: 100% (35115/35115), done.

# %%
# %cd ActorRecognizer
# Out:
# /content/ActorRecognizer

# %%
# %run '[VGG]Treniranje konvolutivnih slojeva vgg modela sa vize razlicitih parametara ucenja.ipynb'
# Out:
# Total number of individuals: 105
#
# Name of the individuals :
# ...
